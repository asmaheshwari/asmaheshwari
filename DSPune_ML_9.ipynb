# %%
# In this assignment students have to compress racoon grey scale image into 5 clusters. In
# the end, visualize both raw and compressed image and look for quality difference.
# The raw image is available in spicy.misc package with the name face.

# %%
import numpy as np
from sklearn import cluster, datasets
from scipy import misc

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# help(scipy.misc.face)

# %%
z = misc.face(gray=True)
plt.figure(figsize=(10, 6))
plt.imshow(z, cmap=plt.cm.gray)
plt.show()

# %%
row = z.shape[0]
col = z.shape[1]

# %%
row, col
# Out:
# (768, 1024)

# %%
image = f.reshape(row*col,1)

# %%
image
# Out:
# array([[114],
#        [130],
#        [145],
#        ...,
#        [142],
#        [141],
#        [140]], dtype=uint8)

# %%
kmeans = cluster.KMeans(n_clusters = 5)

# %%
kmeans.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = np.asarray(kmeans.cluster_centers_) 
labels = np.asarray(kmeans.labels_)  
labels = labels.reshape(row,col);

# %%
# Save Image after compression
plt.imsave('racoon.jpg',labels);

# %%
# Visualize the compressed image

savedimage = plt.imread('racoon.jpg')
plt.figure(figsize=(10, 6))
plt.imshow(savedimage)
plt.show()
